# %%
import pandas as pd
pd.options.display.max_columns = None

# %%
path = "/Users/Jake/Downloads/"
xcel_file = pd.read_excel(path+"aaq0216_DataS2.xls")
col_names = xcel_file.iloc[1]
#xcel_file = xcel_file[2:]
#xcel_file.columns = col_names
xcel_file

#land_use = xcel_file[xcel_file.columns[0:7,9]]

land_use = xcel_file.iloc[:,np.r_[0:7]]
land_use.columns = land_use.iloc[1]
land_use = land_use[2:]
land_use.set_index("Product")


ghg = xcel_file.iloc[:,np.r_[0,7:13]]
ghg.columns = ghg.iloc[1]
ghg = ghg[2:]
ghg = ghg.set_index("Product")


#xcel_file.set_index("Unnamed: 0")
ghg.drop(df.tail(n).index,inplace=True)
# Out:
# 1                                                  5th pctl 10th pctl   Mean  \
# Product
# Wheat & Rye (Bread)                                    0.71      0.79   1.57
# Maize (Meal)                                           0.66      0.73    1.7
# Barley (Beer)                                          0.59       0.7   1.18
# Oatmeal                                                 0.8      0.85   2.48
# Rice                                                   1.15      1.46   4.45
# Potatoes                                               0.09      0.16   0.46
# Cassava                                                0.26      0.35   1.32
# Cane Sugar                                             0.62      0.92    3.2
# Beet Sugar                                             1.01      1.21   1.81
# Other Pulses                                           0.89      0.98   1.79
# Peas                                                   0.51      0.56   0.98
# ...

# %%
list(xcel_file)
# Out:
# ['Unnamed: 0',
#  'Resampled, Randomized Data',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Unnamed: 33',
#  'Unnamed: 34',
#  'Unnamed: 35',
#  'Unnamed: 36',
#  'Unnamed: 37',
#  'Unnamed: 38',
#  'Unnamed: 39',
#  'Unnamed: 40',
#  'Unnamed: 41',
#  'Unnamed: 42',
#  'Data Without Resampling or Randomization (original study data, after harmonizing methodology)',
#  'Unnamed: 44',
#  'Unnamed: 45',
#  'Unnamed: 46',
#  'Unnamed: 47',
#  'Unnamed: 48',
#  'Unnamed: 49',
# ...

# %%
xcel_file
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                             Product
# 2                                 Wheat & Rye (Bread)
# 3                                        Maize (Meal)
# 4                                       Barley (Beer)
# 5                                             Oatmeal
# 6                                                Rice
# 7                                            Potatoes
# 8                                             Cassava
# 9                                          Cane Sugar
# 10                                         Beet Sugar
# 11                                       Other Pulses
# 12                                               Peas
# 13                                               Nuts
# 14                                         Groundnuts
# 15                                            Soymilk
# ...

# %%
xcel_file.set_index("Unnamed: 0")
# Out:
#                                                    Resampled, Randomized Data  \
# Unnamed: 0
# NaN                                                          Land Use (m2/FU)
# Product                                                              5th pctl
# Wheat & Rye (Bread)                                                      0.98
# Maize (Meal)                                                             0.99
# Barley (Beer)                                                            0.21
# Oatmeal                                                                  2.64
# Rice                                                                     0.99
# Potatoes                                                                 0.37
# Cassava                                                                  0.73
# Cane Sugar                                                               1.14
# Beet Sugar                                                               1.11
# ...
